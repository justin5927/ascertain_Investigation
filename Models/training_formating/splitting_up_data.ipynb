# %%
import os 
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Paths
data_path = "../../data/"
features_path = os.path.join(data_path, "pca_features.csv")
personalities_path = os.path.join(data_path, "personalities.csv")

# %%
# Load dataframes
features_df = pd.read_csv(features_path)
personalities_df = pd.read_csv(personalities_path)

# %%
personalities_df
# Out:
#       participants  recordings  Extraversion  Agreeableness  \
# 0              0.0         0.0           5.4            5.9
# 1              0.0         1.0           5.4            5.9
# 2              0.0         2.0           5.4            5.9
# 3              0.0         3.0           5.4            5.9
# 4              0.0         4.0           5.4            5.9
# ...            ...         ...           ...            ...
# 2083          57.0        31.0           4.6            6.5
# 2084          57.0        32.0           4.6            6.5
# 2085          57.0        33.0           4.6            6.5
# 2086          57.0        34.0           4.6            6.5
# 2087          57.0        35.0           4.6            6.5
#
#       Conscientiousness  Emotional Stability  Openness Extraversion_bin  \
# 0                   5.2                  5.1       5.2         positive
# 1                   5.2                  5.1       5.2         positive
# ...

# %%
features_df
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.051983  0.209130 -0.042102  0.498430 -0.174835 -0.182203  0.139295
# 1     0.312953 -0.115445 -0.401069  0.156860 -0.239359 -0.008556 -0.123941
# 2     0.060859 -0.559511  0.122128  0.398456 -0.161544 -0.225310  0.219489
# 3     0.032434 -0.277673 -0.163622 -0.369103 -0.124992  0.151663  0.035271
# 4     0.427993 -0.006418 -0.115873  0.074329 -0.349656  0.098716  0.059161
# ...        ...       ...       ...       ...       ...       ...       ...
# 2072  0.395300 -0.158381  0.439793 -0.057501 -0.066365  0.079617 -0.330527
# 2073  1.120207 -0.280032  0.239052 -0.094579 -0.023530 -0.010054 -0.139612
# 2074  0.370058 -0.785001  0.406512 -0.146910  0.219843  0.057389 -0.094547
# 2075 -0.020143 -0.224005  0.511328 -0.125384  0.168249 -0.000471 -0.249435
# 2076 -0.012241 -0.036700  0.671122 -0.100531  0.166610  0.032103 -0.231081
#
#            PC8  participants  recordings
# ...

# %%
# For df1
X1 = df1.drop('target_column_name', axis=1)  # Replace 'target_column_name' with the name of your target column
y1 = df1['target_column_name']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=42)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %%
# Save train and test sets for df1
X1_train.to_csv('X1_train.csv', index=False)
X1_test.to_csv('X1_test.csv', index=False)
y1_train.to_csv('y1_train.csv', index=False)
y1_test.to_csv('y1_test.csv', index=False)

# Save train and test sets for df2
X2_train.to_csv('X2_train.csv', index=False)
X2_test.to_csv('X2_test.csv', index=False)
y2_train.to_csv('y2_train.csv', index=False)
y2_test.to_csv('y2_test.csv', index=False)
