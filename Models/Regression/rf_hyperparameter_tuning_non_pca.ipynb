# %%
import os
import pickle
import pandas as pd
from multiprocessing import Pool
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error, make_scorer

# %%
# Load data
data_path = "../../data"
X_train = pd.read_csv(os.path.join(data_path, "X_train.csv"))
y_train_org = pd.read_csv(os.path.join(data_path, "y_train.csv"))
X_test = pd.read_csv(os.path.join(data_path, "X_test.csv"))
y_test_org = pd.read_csv(os.path.join(data_path, "y_test.csv"))

# %%
traits = ['Extraversion', 'Agreeableness', 'Conscientiousness', 'Emotional Stability', 'Openness']
random_state=27

# %%
# Create results directory
results_path = "../../results"
specific_results_path = os.path.join("../../results", "rf_regression_non_pca")
os.makedirs(results_path, exist_ok=True)
os.makedirs(specific_results_path, exist_ok=True)

# %%
# Define the parameter grid you want to search over
param_grid = {
    'n_estimators': [100,150,200,250,300],  # Number of trees in the forest
    'max_depth': [None, 10,15,20,25,30],  # Maximum depth of the trees
    'min_samples_split': [2,3,4,5,6,8,10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 3, 4, 5]    # Minimum number of samples required to be at a leaf node
}
r2_scorer = make_scorer(r2_score)

# Create a Random Forest Regressor model
rf = RandomForestRegressor(random_state=42)

# Create a grid search object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, scoring=r2_scorer, cv=3, n_jobs=5)

for trait in traits:
    print(f"Processing {trait}")
    y_train = y_train_org[trait]
    y_test = y_test_org[trait]
    # Fit the grid search to your data
    grid_search.fit(X_train, y_train)

    # Print the best hyperparameters and the corresponding score
    print("Best Hyperparameters: ", grid_search.best_params_)
    print("Best Score: ", -grid_search.best_score_)

    # Get the best model from the grid search
    best_rf = grid_search.best_estimator_

    # Now, you can use the best_rf model for predictions on your test data
    y_pred = best_rf.predict(X_test)
    y_true = y_test
    # Compute metrics
    # Calculate Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    # Calculate Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    # Calculate Root Mean Squared Error (RMSE)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    # Calculate R-squared (R2) Score
    r2 = r2_score(y_true, y_pred)
    # Calculate Mean Absolute Percentage Error (MAPE)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    # Calculate Mean Percentage Error (MPE)
    mpe = (1/len(y_true)) * sum(((y_true[i] - y_pred[i]) / y_true[i]) * 100 for i in range(len(y_true)))

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Squared Error (MSE):", mse)
    print("Root Mean Squared Error (RMSE):", rmse)
    print("R-squared (R2) Score:", r2)
    print("Mean Absolute Percentage Error (MAPE):", mape)
    print("Mean Percentage Error (MPE):", mpe)
    print("\n\n")

    # Add metrics to dict
    metrics = {"mae": mae, "mse": mse, "rmse": rmse, "r2": r2, "mape": mape, "best_hyperparameters": grid_search.best_params_, "best_score": grid_search.best_score_}

    # Save model and metrics 
    curr_result_path = os.path.join(specific_results_path, trait)
    os.makedirs(curr_result_path, exist_ok=True)
    with open(os.path.join(curr_result_path, f'rf_model_tuned.pkl'), 'wb') as file:
        pickle.dump(best_rf, file)
    with open(os.path.join(curr_result_path, f'perf_metrics_tuned.pkl'), 'wb') as file:
        pickle.dump(metrics, file)
# Out:
# Processing Extraversion
# Best Hyperparameters:  {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 250}
# Best Score:  -0.26839042835931554
# Mean Absolute Error (MAE): 0.7299730769230764
# Mean Squared Error (MSE): 0.7580140369230762
# Root Mean Squared Error (RMSE): 0.8706400156913742
# R-squared (R2) Score: 0.3493967104438449
# Mean Absolute Percentage Error (MAPE): 0.18478677168423785
# Mean Percentage Error (MPE): -4.722343780255897
#
#
#
# Processing Agreeableness
# Best Hyperparameters:  {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Best Score:  -0.28184708142314574
# Mean Absolute Error (MAE): 0.5041939423172842
# Mean Squared Error (MSE): 0.41056235378638833
# Root Mean Squared Error (RMSE): 0.6407513978029141
# R-squared (R2) Score: 0.36214162737315414
# Mean Absolute Percentage Error (MAPE): 0.09974744018577632
# Mean Percentage Error (MPE): -0.05357570354550017
#
#
#
# Processing Conscientiousness
# Best Hyperparameters:  {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 250}
# Best Score:  -0.27917139722042467
# Mean Absolute Error (MAE): 0.5154343941787562
# Mean Squared Error (MSE): 0.46251668151430486
# Root Mean Squared Error (RMSE): 0.6800857898194204
# R-squared (R2) Score: 0.21696150302488726
# Mean Absolute Percentage Error (MAPE): 0.10114044089854494
# Mean Percentage Error (MPE): -0.3035657347835765
#
#
#
# Processing Emotional Stability
# Best Hyperparameters:  {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 150}
# Best Score:  -0.31911053023399455
# Mean Absolute Error (MAE): 0.5532572494879099
# Mean Squared Error (MSE): 0.5128171207206649
# Root Mean Squared Error (RMSE): 0.71611250563069
# R-squared (R2) Score: 0.2729878721365895
# Mean Absolute Percentage Error (MAPE): 0.13468833183671075
# Mean Percentage Error (MPE): 0.22764518724227992
#
#
#
# Processing Openness
# Best Hyperparameters:  {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 100}
# Best Score:  -0.27461384142346357
# Mean Absolute Error (MAE): 0.42124360497821667
# Mean Squared Error (MSE): 0.3483833315570708
# Root Mean Squared Error (RMSE): 0.5902400626499956
# R-squared (R2) Score: 0.25096389973571276
# Mean Absolute Percentage Error (MAPE): 0.08362802224443272
# Mean Percentage Error (MPE): -0.8824857426918102
